# %%
import pandas as pd

#streetcar data
df1 = pd.read_csv('../raw/streetcar/streetcar_2020.csv')
df2 = pd.read_csv('../raw/streetcar/streetcar_2021.csv')
df3 = pd.read_csv('../raw/streetcar/streetcar_2022.csv')
df4 = pd.read_csv('../raw/streetcar/streetcar_2023.csv')
df5 = pd.read_csv('../raw/streetcar/streetcar_2024.csv')
df6 = pd.read_csv('../raw/streetcar/streetcar_2025.csv')

# %%
print(df1.info())
print(df2.info())
print(df3.info())
print(df4.info())
print(df5.info())
print(df6.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 802 entries, 0 to 801
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Report Date  802 non-null    str
#  1   Route        802 non-null    int64
#  2   Time         802 non-null    str
#  3   Day          802 non-null    str
#  4   Location     801 non-null    str
#  5   Incident     802 non-null    str
#  6   Delay        802 non-null    int64
#  7   Gap          802 non-null    int64
#  8   Direction    802 non-null    str
#  9   Vehicle      791 non-null    float64
# dtypes: float64(1), int64(3), str(6)
# memory usage: 108.0 KB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1018 non-null   str
#  1   Line       1016 non-null   str
#  2   Time       1018 non-null   str
#  3   Day        1018 non-null   str
#  4   Location   1018 non-null   str
#  5   Incident   1018 non-null   str
#  6   Min Delay  1018 non-null   int64
#  7   Min Gap    1018 non-null   int64
#  8   Bound      934 non-null    str
#  9   Vehicle    1018 non-null   int64
# dtypes: int64(3), str(7)
# memory usage: 134.5 KB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 17655 entries, 0 to 17654
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       17655 non-null  str
#  1   Line       17612 non-null  str
#  2   Time       17655 non-null  str
#  3   Day        17655 non-null  str
#  4   Location   17655 non-null  str
#  5   Incident   17655 non-null  str
#  6   Min Delay  17655 non-null  int64
#  7   Min Gap    17655 non-null  int64
#  8   Bound      14606 non-null  str
#  9   Vehicle    17655 non-null  int64
# dtypes: int64(3), str(7)
# memory usage: 2.3 MB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 14413 entries, 0 to 14412
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       14413 non-null  str
#  1   Line       14285 non-null  str
#  2   Time       14413 non-null  str
#  3   Day        14413 non-null  str
#  4   Location   14413 non-null  str
#  5   Incident   14413 non-null  str
#  6   Min Delay  14413 non-null  int64
#  7   Min Gap    14413 non-null  int64
#  8   Bound      12173 non-null  str
#  9   Vehicle    14413 non-null  int64
# dtypes: int64(3), str(7)
# memory usage: 1.9 MB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 14206 entries, 0 to 14205
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       14206 non-null  str
#  1   Line       14050 non-null  str
#  2   Time       14206 non-null  str
#  3   Day        14206 non-null  str
#  4   Location   14205 non-null  str
#  5   Incident   14206 non-null  str
#  6   Min Delay  14206 non-null  int64
#  7   Min Gap    14206 non-null  int64
#  8   Bound      12078 non-null  str
#  9   Vehicle    14206 non-null  int64
# dtypes: int64(3), str(7)
# memory usage: 1.9 MB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 15785 entries, 0 to 15784
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   _id        15785 non-null  int64
#  1   Date       15785 non-null  str
#  2   Line       15555 non-null  str
#  3   Time       15785 non-null  str
#  4   Day        15785 non-null  str
#  5   Station    15785 non-null  str
#  6   Code       15785 non-null  str
#  7   Min Delay  15785 non-null  int64
#  8   Min Gap    15785 non-null  int64
#  9   Bound      12554 non-null  str
#  10  Vehicle    15785 non-null  int64
# dtypes: int64(4), str(7)
# memory usage: 2.2 MB
# None

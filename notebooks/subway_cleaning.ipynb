# %%
import pandas as pd

#subway data
df1 = pd.read_csv('../raw/subway/subway_2020.csv')
df2 = pd.read_csv('../raw/subway/subway_2021.csv')
df3 = pd.read_csv('../raw/subway/subway_2022.csv')
df4 = pd.read_csv('../raw/subway/subway_2023.csv')
df5 = pd.read_csv('../raw/subway/subway_2024.csv')
df6 = pd.read_csv('../raw/subway/subway_2025.csv')

# %%
print(df1.info())
print(df2.info())
print(df3.info())
print(df4.info())
print(df5.info())
print(df6.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1339 entries, 0 to 1338
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1339 non-null   str
#  1   Time       1339 non-null   str
#  2   Day        1339 non-null   str
#  3   Station    1339 non-null   str
#  4   Code       1339 non-null   str
#  5   Min Delay  1339 non-null   int64
#  6   Min Gap    1339 non-null   int64
#  7   Bound      1020 non-null   str
#  8   Line       1339 non-null   str
#  9   Vehicle    1339 non-null   int64
# dtypes: int64(3), str(7)
# memory usage: 165.2 KB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 1216 entries, 0 to 1215
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1216 non-null   str
#  1   Time       1216 non-null   str
#  2   Day        1216 non-null   str
#  3   Station    1216 non-null   str
#  4   Code       1216 non-null   str
#  5   Min Delay  1216 non-null   int64
#  6   Min Gap    1216 non-null   int64
#  7   Bound      924 non-null    str
#  8   Line       1212 non-null   str
#  9   Vehicle    1216 non-null   int64
# dtypes: int64(3), str(7)
# memory usage: 150.1 KB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 19895 entries, 0 to 19894
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       19895 non-null  str
#  1   Time       19895 non-null  str
#  2   Day        19895 non-null  str
#  3   Station    19895 non-null  str
#  4   Code       19895 non-null  str
#  5   Min Delay  19895 non-null  int64
#  6   Min Gap    19895 non-null  int64
#  7   Bound      14349 non-null  str
#  8   Line       19856 non-null  str
#  9   Vehicle    19895 non-null  int64
# dtypes: int64(3), str(7)
# memory usage: 2.4 MB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 22949 entries, 0 to 22948
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       22949 non-null  str
#  1   Time       22949 non-null  str
#  2   Day        22949 non-null  str
#  3   Station    22949 non-null  str
#  4   Code       22949 non-null  str
#  5   Min Delay  22949 non-null  int64
#  6   Min Gap    22949 non-null  int64
#  7   Bound      14423 non-null  str
#  8   Line       22901 non-null  str
#  9   Vehicle    22949 non-null  int64
# dtypes: int64(3), str(7)
# memory usage: 2.8 MB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 26467 entries, 0 to 26466
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       26467 non-null  str
#  1   Time       26467 non-null  str
#  2   Day        26467 non-null  str
#  3   Station    26467 non-null  str
#  4   Code       26467 non-null  str
#  5   Min Delay  26467 non-null  int64
#  6   Min Gap    26467 non-null  int64
#  7   Bound      16947 non-null  str
#  8   Line       26423 non-null  str
#  9   Vehicle    26467 non-null  int64
# dtypes: int64(3), str(7)
# memory usage: 3.2 MB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 28191 entries, 0 to 28190
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   _id        28191 non-null  int64
#  1   Date       28191 non-null  str
#  2   Time       28191 non-null  str
#  3   Day        28191 non-null  str
#  4   Station    28191 non-null  str
#  5   Code       28191 non-null  str
#  6   Min Delay  28191 non-null  int64
#  7   Min Gap    28191 non-null  int64
#  8   Bound      17961 non-null  str
#  9   Line       28116 non-null  str
#  10  Vehicle    28191 non-null  int64
# dtypes: int64(4), str(7)
# memory usage: 3.6 MB
# None

# %%
#only df6 has a extra column that can be dropped
df6 = df6.drop(columns=['_id'])

# %%
dfs = [df1, df2, df3, df4, df5, df6]
if all(set(dfs[0].columns) == set(df.columns) for df in dfs):
    print("All DataFrames have the same columns.")
else:
    print("Some DataFrames have different columns.")
# Out:
# All DataFrames have the same columns.

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6], ignore_index=True)

# %%
df
# Out:
#               Date   Time        Day                 Station   Code  \
# 0       2020-01-01  01:18  Wednesday     KENNEDY SRT STATION   SRDP
# 1       2020-01-01  01:27  Wednesday   SHEPPARD WEST STATION    MUI
# 2       2020-01-01  02:22  Wednesday     MAIN STREET STATION   EUNT
# 3       2020-01-01  03:54  Wednesday         KIPLING STATION   MUIS
# 4       2020-01-01  08:07  Wednesday           KEELE STATION  MUNOA
# ...            ...    ...        ...                     ...    ...
# 100052  2026-01-31  01:54   Saturday           BLOOR STATION   MUIS
# 100053  2026-01-31  01:59   Saturday      YORK MILLS STATION   PUTO
# 100054  2026-01-31  03:14   Saturday         BAYVIEW STATION   PUTO
# 100055  2026-01-31  06:00   Saturday  SHEPPARD-YONGE STATION   MUCP
# 100056  2026-01-31  09:46   Saturday       DON MILLS STATION    MUO
#
#         Min Delay  Min Gap Bound Line  Vehicle
# 0               8       13     N  SRT     3025
# 1               7       12     S   YU     5591
# 2               3        7     W   BD     5371
# 3               0        0     E   BD     5243
# 4               4        9     W   BD     5011
# ...           ...      ...   ...  ...      ...
# 100052          0        0   NaN   YU        0
# 100053         12       18     N   YU     5761
# 100054          0        0   NaN  SHP        0
# 100055          0        0   NaN  SHP        0
# 100056          0        0   NaN  SHP        0
#
# [100057 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100057 entries, 0 to 100056
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       100057 non-null  str
#  1   Time       100057 non-null  str
#  2   Day        100057 non-null  str
#  3   Station    100057 non-null  str
#  4   Code       100057 non-null  str
#  5   Min Delay  100057 non-null  int64
#  6   Min Gap    100057 non-null  int64
#  7   Bound      65624 non-null   str
#  8   Line       99847 non-null   str
#  9   Vehicle    100057 non-null  int64
# dtypes: int64(3), str(7)
# memory usage: 12.0 MB

# %%
#bound and line has NULL
df.Bound.unique()
# Out:
# <ArrowStringArray>
# ['N', 'S', 'W', 'E', nan, 'B']
# Length: 6, dtype: str
